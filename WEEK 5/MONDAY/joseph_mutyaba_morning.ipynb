# %% [markdown]
# # Supervised Learning
# Labelled data
# ### linear regression, classification
# ### e.g.
# Decision trees
#
# # Unsupervised Learning
# Clustering algorithms
# ### e.g.
# PCA, k-means clustering
#
# # Reinforcement learning
# Deals with signals, interacts with env and rewards
#
# ## Steps
# 1. Problem Definition
# 2. Gather data
# 3. Split data

# %% [markdown]
# # 3 Categories of data
# 1. Nummerical data -> can be dicrete or continuous
# 2. Categorical data
# 3. Ordinal data

# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('heart_disease.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
"""
    cp- chest pain
    trestbps-resting blood pressure
    fbs-fasting blood pressure
    restcg- resting electrocardiography
    exang- exercise induced agina
    oldpeak- st depression induced
    slope- slope of peak exercise
    ca- number of major vessel
    thal-
"""
# Out:
# '\n    cp- chest pain\n    trestbps-resting blood pressure\n    fbs-fasting blood pressure\n    restcg- resting electrocardiography\n    exang- exercise induced agina\n    oldpeak- st depression induced\n    slope- slope of peak exercise\n    ca- number of major vessel\n    thal-\n'

# %%
# show number of people with heart disease 
df.target.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
# show percentage of male and female
count_male=len(df[df.sex==0])
count_female=len(df[df.sex==1])
print("Percentage of female patients: {:.2f}%".format((count_female/len(df.sex))*100))
print("Percentage of male patients: {:.2f}%".format((count_male/len(df.sex))*100))
# Out:
# Percentage of female patients: 69.56%
# Percentage of male patients: 30.44%

# %%
pd.crosstab(df.age, df.target).plot(kind='bar' , figsize=(20,6))
plt.title("Heart disease frequency for ages")
plt.xlabel("Ages")
plt.ylabel("Frequency ")
# Out:
# Text(0, 0.5, 'Frequency ')

# %%
# Plot a visualization Heart Disease Frequency for sex
pd.crosstab(df.sex, df.target).plot(kind='bar' , figsize=(20,6))
plt.title("Heart disease frequency for Sex")
plt.xticks(rotation=0)
plt.xlabel("Sex")
plt.ylabel("Frequency ")
# Out:
# Text(0, 0.5, 'Frequency ')

# %%
age = df['age']
chol = df['chol']

# Create scatter plot
plt.scatter(age, chol, c=df['target'], cmap='coolwarm')
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.title('Scatter Plot: Age vs Cholesterol')
plt.colorbar(label='Target')
plt.show()

# %%
# Create a model for logistic regression
# Solve problem based on clasifiation

# create ddependent and independent variables
#Categorical prediction

# %%
#Read Decision trees
#testing and training, dependent and independent variables

# %%
# Creating a mode for logistic regression
y=df.target.values
x_data=df.drop(['target'], axis=1)

# %%
# Split data

# %%
# Normalise data
# split data for training and testing
#80%-training and 20%-test
x=(x_data-np.min(x_data))/(np.max(x_data)-np.min(x_data))
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# C:\Users\USER\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
x_train,x_test, y_train, y_test=train_test_split(x,y, test_size=0.3,random_state=0)

# %%
x_train=x_train.T
y_train=y_train.T
x_test=x_train.T
y_test=y_train.T
