# %%
import pandas as pd

# %%
df= pd.read_csv('bse_dataset4.csv')

# %%
#shape
df.shape
# Out:
# (169, 15)

# %%
#columns
df.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
df_new=df.dropna()
df_new
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# 13   05/07/2023 09:39:40           MALE  22.0                  fine
# ...

# %%
df
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# shows display of all rows an columns
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
df
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
print(df.to_string())
# Out:
#                Timestamp         gender   Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male  21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           168 non-null    object
#  1   gender                                              169 non-null    object
#  2   Age                                                 167 non-null    float64
#  3   emotion                                             168 non-null    object
#  4   YOB                                                 169 non-null    object
#  5   CGPA                                                169 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             169 non-null    object
#  7   Do you have Depression?                             169 non-null    object
# ...

# %%
# calculate median
# empty cells, wrong format, wrong data, duplicates

calories_median=df['Calories'].median()
df['Calories'].fillna(calories_median,inplace=True)
print(calories_median)
# Out:
# 318.6

# %%
df
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
#Exercise 1:
# mode on age


med_age=df['Age'].mode()
df['Age'].fillna(med_age, inplace=True)

# %%
#wrong format row that is very difficult(NaN, )
df['Timestamp'].fillna('05/07/2023 09:45:13', inplace=True)

# %%
df
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5    05/07/2023 09:45:13         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
for x in df.index:
    if df.loc[x,'gender']=='Marabou stock':
        df.drop(x, inplace=True)

# %%
print(df.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# ...

# %%
df.drop_duplicates()
# Out:
#                Timestamp   gender   Age               emotion            YOB  \
# 0    05/07/2023 09:38:39     Male  21.0               Content           2002
# 2    05/07/2023 09:39:09  Female   20.0                 Happy           2002
# 3    05/07/2023 09:39:12     Male  21.0                 Happy           2003
# 4    05/07/2023 09:39:14   Female  21.0                 Happy           2002
# 5    05/07/2023 09:45:13   Female  23.0                Happy            2000
# 6    05/07/2023 09:39:21   female  21.0            irritated            2001
# 7    05/07/2023 09:39:23  Female   22.0  In a state of wonder           2001
# 8    05/07/2023 09:39:26     Male  22.0                   Sad           2001
# 9    05/07/2023 09:39:27   Female  20.0                 happy           2002
# 10            2023/12/26     Male  24.0                 Happy           1998
# 12   05/07/2023 09:39:38     Male  25.0                 Happy           1998
# ...

# %%
# data visualisation, matplotlib
#heatmap, bargraph, histogram, piechart, scatter plot, line-plot
import matplotlib.pyplot as plt
df['Age'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['Age'].plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='Age'>

# %%
df['Age'].plot(kind='bar')
# Out:
# <AxesSubplot: >
